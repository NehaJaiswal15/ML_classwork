# %% [markdown]
# ## CSV and Excel

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
df_csv = pd.read_csv("my_data(csv).csv") 
df_csv.head() 
df_excel = pd.read_excel("my_data.xlsx", sheet_name="Sheet1") 
df_excel.head()
# Out:
#    Name  Age   City
# 0  Sara   29  tokyo
# 1   Ali   30  cairo

# %%
df_csv.info()
df_excel.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      object
#  1   Age     2 non-null      int64
#  2   City    2 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 180.0+ bytes
#              Age
# count   2.000000
# mean   29.500000
# std     0.707107
# min    29.000000
# 25%    29.250000
# 50%    29.500000
# 75%    29.750000
# max    30.000000

# %%
df_csv.to_excel("exported_data.xlsx", index=False)
df_excel.to_csv("exported_data.csv", index=False)

# %% [markdown]
# ## REST API

# %%
import requests
import pandas as pd

# %%
url = "https://jsonplaceholder.typicode.com/users"

response = requests.get(url)

data = response.json()

data
# Out:
# [{'id': 1,
#   'name': 'Leanne Graham',
#   'username': 'Bret',
#   'email': 'Sincere@april.biz',
#   'address': {'street': 'Kulas Light',
#    'suite': 'Apt. 556',
#    'city': 'Gwenborough',
#    'zipcode': '92998-3874',
#    'geo': {'lat': '-37.3159', 'lng': '81.1496'}},
#   'phone': '1-770-736-8031 x56442',
#   'website': 'hildegard.org',
#   'company': {'name': 'Romaguera-Crona',
#    'catchPhrase': 'Multi-layered client-server neural-net',
#    'bs': 'harness real-time e-markets'}},
#  {'id': 2,
#   'name': 'Ervin Howell',
#   'username': 'Antonette',
#   'email': 'Shanna@melissa.tv',
#   'address': {'street': 'Victor Plains',
#    'suite': 'Suite 879',
#    'city': 'Wisokyburgh',
#    'zipcode': '90566-7771',
#    'geo': {'lat': '-43.9509', 'lng': '-34.4618'}},
#   'phone': '010-692-6593 x09125',
#   'website': 'anastasia.net',
#   'company': {'name': 'Deckow-Crist',
#    'catchPhrase': 'Proactive didactic contingency',
#    'bs': 'synergize scalable supply-chains'}},
# ...

# %%
df_api = pd.DataFrame(data)
df_api
# Out:
#    id                      name          username                      email  \
# 0   1             Leanne Graham              Bret          Sincere@april.biz
# 1   2              Ervin Howell         Antonette          Shanna@melissa.tv
# 2   3          Clementine Bauch          Samantha         Nathan@yesenia.net
# 3   4          Patricia Lebsack          Karianne  Julianne.OConner@kory.org
# 4   5          Chelsey Dietrich            Kamren   Lucio_Hettinger@annie.ca
# 5   6      Mrs. Dennis Schulist  Leopoldo_Corkery    Karley_Dach@jasper.info
# 6   7           Kurtis Weissnat      Elwyn.Skiles     Telly.Hoeger@billy.biz
# 7   8  Nicholas Runolfsdottir V     Maxime_Nienow       Sherwood@rosamond.me
# 8   9           Glenna Reichert          Delphine    Chaim_McDermott@dana.io
# 9  10        Clementina DuBuque    Moriah.Stanton     Rey.Padberg@karina.biz
#
#                                              address                  phone  \
# ...

# %%
df_api["name"]
# Out:
# 0               Leanne Graham
# 1                Ervin Howell
# 2            Clementine Bauch
# 3            Patricia Lebsack
# 4            Chelsey Dietrich
# 5        Mrs. Dennis Schulist
# 6             Kurtis Weissnat
# 7    Nicholas Runolfsdottir V
# 8             Glenna Reichert
# 9          Clementina DuBuque
# Name: name, dtype: object

# %% [markdown]
# ## SQL DATABASE

# %%
import pymysql
import pandas as pd

# %%
conn = pymysql.connect(
    host="localhost",
    user="root",
    password="*Neha2004*",
    database="data_collection_db"
    )

# %%
query = "SELECT * FROM employees;" 

df_mysql = pd.read_sql(query, conn)
df_mysql
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_14972\3988604416.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql = pd.read_sql(query, conn)
#    emp_id   name department
# 0       1  Alice       Tech
# 1       2    Bob         HR
# 2       3  Ankur       Tech
# 3       4  Alaya   Director
# 4       5   Anup       Tech
# 5       6  Aisha        CEO
# 6       7   Aman   NON-Tech
# 7       8  Milli  Marketing

# %%
conn.close()

# %% [markdown]
# ## from local folder

# %%
import cv2
import os
import matplotlib.pyplot as plt

# %%
folder_path = r"C:\\Users\\KIIT0001\\Pictures\\picturesss"

# %%
images = []

for file in os.listdir(folder_path):
    if file.lower().endswith((".png", ".jpg", ".jpeg")):
        path = os.path.join(folder_path, file)
        img = cv2.imread(path)
        images.append((file, img))

len(images)
# Out:
# 2

# %%
filename, img = images[1]

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.title(filename)
plt.axis("off")
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %% [markdown]
# ## cloud storage

# %%
import pandas as pd
df = pd.read_csv("my_data(csv).csv")
df
# Out:
#    Name  Age   City
# 0  Sara   29  tokyo
# 1   Ali   30  cairo

# %%
file_id = "1c1_Nge4AmsOlUBnIxkfXMPp_5HsYweLm"
url = f"https://drive.google.com/uc?id={file_id}"

df = pd.read_csv(url)
df
# Out:
#    Name  Age   City
# 0  Sara   29  tokyo
# 1   Ali   30  cairo

# %% [markdown]
# ## Log file

# %%
log_path = r"C:\\Users\\KIIT0001\\Desktop\\ML classwork\\data_collection\\server.log"

with open(log_path, "r") as file:
    logs = file.readlines()

logs[:5]
# Out:
# ['2025-12-02 10:15:32 INFO User logged in: user123\n',
#  '2025-12-02 10:16:01 ERROR Failed login attempt for user999\n',
#  '2025-12-02 10:17:45 WARNING Password attempt limit reached\n',
#  '2025-12-02 10:18:22 INFO Session closed for user123']

# %% [markdown]
# ## Json

# %%
import json

with open("data.json", "r") as file:
    data = json.load(file)

data
# Out:
# {'id': 1, 'name': 'Sara', 'age': 24, 'city': 'Cairo'}
